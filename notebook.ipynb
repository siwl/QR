# %%
# %load_ext autoreload
# %autoreload 2

import sys

import pandas as pd
from DataProcess import process_adj_price
from DataLoader import DataLoader
from PathConfig import PathConfig
from utils import AlphaEval
from alpha.nDayRetStd import nDayRetStd
from alpha.nDayRetStdxMean import nDayRetStdxMean
from alpha.nDayRetAbsDev import nDayRetAbsDev

MAX_DAYS=710
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # -std(turnover,N)

# %%
alpha_names = ['turnover_5day_std','turnover_20day_std','turnover_60day_std']
ev = AlphaEval(alpha_names)
ev.compute_pnl()

# %%
ev.plot_pnl()

# %% [markdown]
# # -mean(turover,N), stratified PnL

# %%
alpha_names = ['turnover_5day_mean','turnover_20day_mean','turnover_60day_mean']
ev = AlphaEval(alpha_names)

# %%
ev.compute_pnl()

# %%
ev.plot_pnl(alpha=['turnover_5day_mean'],univ=['all','hs300','zz500','zz800'])

# %% [markdown]
# # Correlation

# %%
ev.compute_corr()

# %%
ev.corr_mat.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_68831">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_68831_level0_col0" class="col_heading level0 col0" >alphaturnover_5day_mean</th>
#       <th id="T_68831_level0_col1" class="col_heading level0 col1" >alphaturnover_20day_mean</th>
#       <th id="T_68831_level0_col2" class="col_heading level0 col2" >alphaturnover_60day_mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_68831_level0_row0" class="row_heading level0 row0" >alphaturnover_5day_mean</th>
#       <td id="T_68831_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_68831_row0_col1" class="data row0 col1" >0.906080</td>
#       <td id="T_68831_row0_col2" class="data row0 col2" >0.823897</td>
#     </tr>
#     <tr>
#       <th id="T_68831_level0_row1" class="row_heading level0 row1" >alphaturnover_20day_mean</th>
#       <td id="T_68831_row1_col0" class="data row1 col0" >0.906080</td>
#       <td id="T_68831_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_68831_row1_col2" class="data row1 col2" >0.928121</td>
#     </tr>
#     <tr>
#       <th id="T_68831_level0_row2" class="row_heading level0 row2" >alphaturnover_60day_mean</th>
#       <td id="T_68831_row2_col0" class="data row2 col0" >0.823897</td>
#       <td id="T_68831_row2_col1" class="data row2 col1" >0.928121</td>
#       <td id="T_68831_row2_col2" class="data row2 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
