# %%
# %load_ext autoreload
# %autoreload 2

import sys

import pandas as pd
from DataProcess import process_adj_price
from DataLoader import DataLoader
from PathConfig import PathConfig
from utils import AlphaEval

MAX_DAYS=710

# %% [markdown]
# # -mean(turover,N), last minunte turnover

# %%
alpha_names = ['turnover_5day_mean','turnover_20day_mean','turnover_60day_mean']
ev = AlphaEval(alpha_names)
ev.compute_pnl()

# %%
ev.plot_pnl(alpha=['turnover_5day_mean'],univ=['all','hs300','zz500','zz800'])

# %% [markdown]
# # -mean(accturnover,N), daily turnover

# %%
alpha_names = ['accturnover_5day_mean','accturnover_20day_mean','accturnover_60day_mean']
ev = AlphaEval(alpha_names)
ev.compute_pnl()

# %%
ev.plot_pnl(alpha=alpha_names,univ=['all'])

# %% [markdown]
# # -std(turover,N), last minute turnover

# %%
alpha_names = ['turnover_5day_std','turnover_20day_std','turnover_60day_std']
ev = AlphaEval(alpha_names)
ev.compute_pnl()

# %%
ev.plot_pnl(alpha=['turnover_5day_std'],univ=['all','hs300','zz500','zz800'])

# %% [markdown]
# # -mean(turover,N)/std(turover,N), std(turover,N)/mean(turover,N)

# %%
alpha_names = ['turnover_5day_meanoverstd','turnover_20day_meanoverstd','turnover_60day_meanoverstd',
              'turnover_5day_stdovermean','turnover_20day_stdovermean','turnover_60day_stdovermean',]
ev = AlphaEval(alpha_names)
ev.compute_pnl()

# %%
ev.plot_pnl(alpha=alpha_names,univ=['all'])

# %% [markdown]
# # mean(vol)/mean(neg_shares)

# %%
alpha_names = ['volume_over_negshare','volume_over_negshare_5day_mean','volume_over_negshare_20day_mean']
ev = AlphaEval(alpha_names)
ev.compute_pnl()

# %%
ev.plot_pnl(alpha=alpha_names,univ=['all'])

# %%
ev.plot_pnl(alpha=['volume_over_negshare'],univ=['all','hs300','zz500','zz800'])

# %% [markdown]
# # Correlation

# %%
alpha_names = ['turnover_20day_stdovermean','turnover_20day_meanoverstd','turnover_5day_mean',
              'accturnover_5day_mean','volume_over_negshare','turnover_5day_std']
ev = AlphaEval(alpha_names)
ev.compute_pnl()

# %%
ev.compute_corr()

# %%
ev.corr_mat.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_1391e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1391e_level0_col0" class="col_heading level0 col0" >alpha_turnover_20day_stdovermean</th>
#       <th id="T_1391e_level0_col1" class="col_heading level0 col1" >alpha_turnover_20day_meanoverstd</th>
#       <th id="T_1391e_level0_col2" class="col_heading level0 col2" >alpha_turnover_5day_mean</th>
#       <th id="T_1391e_level0_col3" class="col_heading level0 col3" >alpha_accturnover_5day_mean</th>
#       <th id="T_1391e_level0_col4" class="col_heading level0 col4" >alpha_volume_over_negshare</th>
#       <th id="T_1391e_level0_col5" class="col_heading level0 col5" >alpha_turnover_5day_std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1391e_level0_row0" class="row_heading level0 row0" >alpha_turnover_20day_stdovermean</th>
#       <td id="T_1391e_row0_col0" class="data row0 col0" >1.000000</td>
# ...
