# %%
# %load_ext autoreload
# %autoreload 2

import sys

from DataProcess import process_adj_price
from DataLoader import DataLoader
from PathConfig import PathConfig
from utils import AlphaEval
from alpha.nDayRetStd import nDayRetStd
from alpha.nDayRetStdxMean import nDayRetStdxMean
from alpha.nDayRetAbsDev import nDayRetAbsDev

MAX_DAYS=710
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
alpha_configs = {'nDayRetAbsDev':{'ndays':60}}

def str_to_class(classname):
    return getattr(sys.modules[__name__], classname)


for alpha,inputs in alpha_configs.items():
    a = str_to_class(alpha)
    a = a(**inputs)
    a.output_csv()

# %% [markdown]
# # -std(ret,N)

# %%
alpha_names = ['nDayRetStd05','nDayRetStd20','nDayRetStd60']
ev = AlphaEval(alpha_names)
ev.compute_pnl()

# %%
ev.plot_pnl()

# %% [markdown]
# # -mad(ret,N)

# %%
alpha_names = ['nDayRetAbsDev05','nDayRetAbsDev20','nDayRetAbsDev60']
ev = AlphaEval(alpha_names)
ev.compute_pnl()

# %%
ev.plot_pnl()

# %% [markdown]
# # -std(ret,N) x mean

# %%
alpha_names = ['nDayRetStdxMean05','nDayRetStdxMean20','nDayRetStdxMean60']
ev = AlphaEval(alpha_names)
ev.compute_pnl()

# %%
ev.plot_pnl()
