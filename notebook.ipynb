# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import matplotlib.pyplot as plt
from alpha.mom10DayAlpha import mom10DayAlpha
from alpha.alphaPerfmc import perfmc
from DataLoader import DataLoader
from PathConfig import PathConfig
from utils import AlphaEval
import sys
from alpha.constVolIntraDay import constVolIntraDay
from alpha.constVolIntraDayReverse import constVolIntraDayReverse

MAX_DAYS=710
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Alpha Generation

# %%
cfg_dict = {'constVolIntraDay':{'const_threshold':1.0}}
def str_to_class(classname):
    return getattr(sys.modules[__name__], classname)
for alpha,inputs in cfg_dict.items():
    a = str_to_class(alpha)
    a = a(**inputs)
    a.output_csv()

# %% [markdown]
# # Const Volume
#
# ## consistent_volume = sum(if(|close - open| <= a|high - low|, min_volume, else 0))

# %%
alpha_names = ['constVolIntraDayp09','constVolIntraDayp01']
ev = AlphaEval(alpha_names)
ev.compute_pnl()

# %%
ev.plot_pnl()

# %% [markdown]
# # Const Buy Volume
#
# ## consistent_volume = sum(if(|close - open| <= a|high - low| & close - open > 0, min_volume, else 0))

# %%
alpha_names = ['constVolIntraDayp09','constVolIntraDayp05']
ev = AlphaEval(alpha_names)
ev.compute_pnl()

# %%
alpha_names = ['constVolIntraDayp09','constVolIntraDayp05']
ev = AlphaEval(alpha_names)
ev.compute_pnl()

# %%
ev.plot_pnl()

# %% [markdown]
# # Const Volume Reverse
#
# ## consistent_volume = sum(if(|close - open| >= a|high - low|, min_volume, else 0))

# %%
alpha_names = ['constVolIntraDayReversep09','constVolIntraDayReversep03','constVolIntraDayReversep09v2']
ev = AlphaEval(alpha_names)
ev.compute_pnl()

# %%
ev.plot_pnl()
